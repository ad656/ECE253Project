# %%
import json
from pathlib import Path
from PIL import Image
import shutil

# Path to your dataset root
root = Path("/home/tzh005/ECE253Project/detecting-the-unexpected/datasets/dataset_RoadAnomaly")

frames_dir = root / "frames"
json_path = root / "frame_list.json"

# Load frame list
frame_list = json.loads(json_path.read_text())

new_frame_list = []
extensions = [".jpg", ".jpeg", ".png", ".JPG", ".JPEG", ".PNG"]

for old_name in frame_list:
    old_path = frames_dir / old_name
    stem = old_path.stem            # e.g., "IMG_4088"
    new_name = stem + ".webp"
    new_path = frames_dir / new_name

    # Convert image → webp
    if old_path.is_file():
        print(f"Converting {old_name} → {new_name}")
        img = Image.open(old_path).convert("RGB")
        img.save(new_path, "webp", quality=95)

        # Optionally delete original (uncomment after verifying results)
        # old_path.unlink()

    # Rename the label folder if it exists
    old_label_dir = frames_dir / (old_name + ".labels")
    if not old_label_dir.exists():
        # Try extension-less folder name
        old_label_dir2 = frames_dir / (stem + ".labels")
        if old_label_dir2.exists():
            old_label_dir = old_label_dir2

    if old_label_dir.exists():
        new_label_dir = frames_dir / (new_name + ".labels")
        print(f"Renaming labels: {old_label_dir.name} → {new_label_dir.name}")
        shutil.move(str(old_label_dir), str(new_label_dir))

    new_frame_list.append(new_name)

# Write new frame_list.json
with open(json_path, "w") as f:
    json.dump(new_frame_list, f, indent=2)

print("Done. Converted all entries to .webp and updated frame_list.json.")
# Out:
# Converting IMG_4088.JPG → IMG_4088.webp
# Renaming labels: IMG_4088.labels → IMG_4088.webp.labels
# Converting IMG_4089.JPG → IMG_4089.webp
# Renaming labels: IMG_4089.labels → IMG_4089.webp.labels
# Converting IMG_4090.JPG → IMG_4090.webp
# Renaming labels: IMG_4090.labels → IMG_4090.webp.labels
# Converting IMG_4091.JPG → IMG_4091.webp
# Renaming labels: IMG_4091.labels → IMG_4091.webp.labels
# Converting IMG_4092.JPG → IMG_4092.webp
# Renaming labels: IMG_4092.labels → IMG_4092.webp.labels
# Converting IMG_4093.JPG → IMG_4093.webp
# Renaming labels: IMG_4093.labels → IMG_4093.webp.labels
# Converting IMG_4094.JPG → IMG_4094.webp
# Renaming labels: IMG_4094.labels → IMG_4094.webp.labels
# Converting IMG_4095.JPG → IMG_4095.webp
# Renaming labels: IMG_4095.labels → IMG_4095.webp.labels
# Converting IMG_4097.JPG → IMG_4097.webp
# Renaming labels: IMG_4097.labels → IMG_4097.webp.labels
# Converting IMG_4098.JPG → IMG_4098.webp
# Renaming labels: IMG_4098.labels → IMG_4098.webp.labels
# Converting IMG_4099.JPG → IMG_4099.webp
# Renaming labels: IMG_4099.labels → IMG_4099.webp.labels
# Converting IMG_4100.JPG → IMG_4100.webp
# Renaming labels: IMG_4100.labels → IMG_4100.webp.labels
# Converting IMG_4101.JPG → IMG_4101.webp
# Renaming labels: IMG_4101.labels → IMG_4101.webp.labels
# Converting Random1205_glared.png → Random1205_glared.webp
# Renaming labels: Random1205_glared.labels → Random1205_glared.webp.labels
# Converting Random1269_glared.png → Random1269_glared.webp
# Renaming labels: Random1269_glared.labels → Random1269_glared.webp.labels
# Converting Random1334_glared.png → Random1334_glared.webp
# Renaming labels: Random1334_glared.labels → Random1334_glared.webp.labels
# Converting Random133_glared.png → Random133_glared.webp
# Renaming labels: Random133_glared.labels → Random133_glared.webp.labels
# Converting Random1360_glared.png → Random1360_glared.webp
# Renaming labels: Random1360_glared.labels → Random1360_glared.webp.labels
# Converting Random1399_glared.png → Random1399_glared.webp
# Renaming labels: Random1399_glared.labels → Random1399_glared.webp.labels
# Converting Random1416_glared.png → Random1416_glared.webp
# Renaming labels: Random1416_glared.labels → Random1416_glared.webp.labels
# Converting Random1498_glared.png → Random1498_glared.webp
# Renaming labels: Random1498_glared.labels → Random1498_glared.webp.labels
# Converting Random149_glared.png → Random149_glared.webp
# Renaming labels: Random149_glared.labels → Random149_glared.webp.labels
# Converting Random154_glared.png → Random154_glared.webp
# Renaming labels: Random154_glared.labels → Random154_glared.webp.labels
# Converting Random15_glared.png → Random15_glared.webp
# Renaming labels: Random15_glared.labels → Random15_glared.webp.labels
# Converting Random166_glared.png → Random166_glared.webp
# Renaming labels: Random166_glared.labels → Random166_glared.webp.labels
# Converting Random167_glared.png → Random167_glared.webp
# Renaming labels: Random167_glared.labels → Random167_glared.webp.labels
# Converting Random1722_glared.png → Random1722_glared.webp
# Renaming labels: Random1722_glared.labels → Random1722_glared.webp.labels
# Converting Random1832_glared.png → Random1832_glared.webp
# Renaming labels: Random1832_glared.labels → Random1832_glared.webp.labels
# Converting Random1974_glared.png → Random1974_glared.webp
# Renaming labels: Random1974_glared.labels → Random1974_glared.webp.labels
# Converting Random1975_glared.png → Random1975_glared.webp
# Renaming labels: Random1975_glared.labels → Random1975_glared.webp.labels
# Converting Random1_glared.png → Random1_glared.webp
# Renaming labels: Random1_glared.labels → Random1_glared.webp.labels
# Converting Random204_glared.png → Random204_glared.webp
# Renaming labels: Random204_glared.labels → Random204_glared.webp.labels
# Converting Random2140_glared.png → Random2140_glared.webp
# Renaming labels: Random2140_glared.labels → Random2140_glared.webp.labels
# Converting Random2161_glared.png → Random2161_glared.webp
# Renaming labels: Random2161_glared.labels → Random2161_glared.webp.labels
# Converting Random2270_glared.png → Random2270_glared.webp
# Renaming labels: Random2270_glared.labels → Random2270_glared.webp.labels
# Converting Random235_glared.png → Random235_glared.webp
# Renaming labels: Random235_glared.labels → Random235_glared.webp.labels
# Converting Random2374_glared.png → Random2374_glared.webp
# Renaming labels: Random2374_glared.labels → Random2374_glared.webp.labels
# Converting Random2494_glared.png → Random2494_glared.webp
# Renaming labels: Random2494_glared.labels → Random2494_glared.webp.labels
# Converting Random24_glared.png → Random24_glared.webp
# Renaming labels: Random24_glared.labels → Random24_glared.webp.labels
# Converting Random2503_glared.png → Random2503_glared.webp
# Renaming labels: Random2503_glared.labels → Random2503_glared.webp.labels
# Converting Random2504_glared.png → Random2504_glared.webp
# Renaming labels: Random2504_glared.labels → Random2504_glared.webp.labels
# Converting Random251_glared.png → Random251_glared.webp
# Renaming labels: Random251_glared.labels → Random251_glared.webp.labels
# Converting Random2545_glared.png → Random2545_glared.webp
# Renaming labels: Random2545_glared.labels → Random2545_glared.webp.labels
# Converting Random2612_glared.png → Random2612_glared.webp
# Renaming labels: Random2612_glared.labels → Random2612_glared.webp.labels
# Converting Random2632_glared.png → Random2632_glared.webp
# Renaming labels: Random2632_glared.labels → Random2632_glared.webp.labels
# Converting Random2669_glared.png → Random2669_glared.webp
# Renaming labels: Random2669_glared.labels → Random2669_glared.webp.labels
# Converting Random2676_glared.png → Random2676_glared.webp
# Renaming labels: Random2676_glared.labels → Random2676_glared.webp.labels
# Converting Random2679_glared.png → Random2679_glared.webp
# Renaming labels: Random2679_glared.labels → Random2679_glared.webp.labels
# Converting Random2680_glared.png → Random2680_glared.webp
# Renaming labels: Random2680_glared.labels → Random2680_glared.webp.labels
# Converting Random26_glared.png → Random26_glared.webp
# Renaming labels: Random26_glared.labels → Random26_glared.webp.labels
# Converting Random2762_glared.png → Random2762_glared.webp
# Renaming labels: Random2762_glared.labels → Random2762_glared.webp.labels
# Converting Random292_glared.png → Random292_glared.webp
# Renaming labels: Random292_glared.labels → Random292_glared.webp.labels
# Converting Random2931_glared.png → Random2931_glared.webp
# Renaming labels: Random2931_glared.labels → Random2931_glared.webp.labels
# Converting Random2975_glared.png → Random2975_glared.webp
# Renaming labels: Random2975_glared.labels → Random2975_glared.webp.labels
# Converting Random3038_glared.png → Random3038_glared.webp
# Renaming labels: Random3038_glared.labels → Random3038_glared.webp.labels
# Converting Random3126_glared.png → Random3126_glared.webp
# Renaming labels: Random3126_glared.labels → Random3126_glared.webp.labels
# Converting Random3139_glared.png → Random3139_glared.webp
# Renaming labels: Random3139_glared.labels → Random3139_glared.webp.labels
# Converting Random31_glared.png → Random31_glared.webp
# Renaming labels: Random31_glared.labels → Random31_glared.webp.labels
# Converting Random3203_glared.png → Random3203_glared.webp
# Renaming labels: Random3203_glared.labels → Random3203_glared.webp.labels
# Converting Random3220_glared.png → Random3220_glared.webp
# Renaming labels: Random3220_glared.labels → Random3220_glared.webp.labels
# Converting Random3270_glared.png → Random3270_glared.webp
# Renaming labels: Random3270_glared.labels → Random3270_glared.webp.labels
# Converting Random3299_glared.png → Random3299_glared.webp
# Renaming labels: Random3299_glared.labels → Random3299_glared.webp.labels
# Converting Random3461_glared.png → Random3461_glared.webp
# Renaming labels: Random3461_glared.labels → Random3461_glared.webp.labels
# Converting Random3568_glared.png → Random3568_glared.webp
# Renaming labels: Random3568_glared.labels → Random3568_glared.webp.labels
# Converting Random358_glared.png → Random358_glared.webp
# Renaming labels: Random358_glared.labels → Random358_glared.webp.labels
# Converting Random385_glared.png → Random385_glared.webp
# Renaming labels: Random385_glared.labels → Random385_glared.webp.labels
# Converting Random386_glared.png → Random386_glared.webp
# Renaming labels: Random386_glared.labels → Random386_glared.webp.labels
# Converting Random461_glared.png → Random461_glared.webp
# Renaming labels: Random461_glared.labels → Random461_glared.webp.labels
# Converting Random473_glared.png → Random473_glared.webp
# Renaming labels: Random473_glared.labels → Random473_glared.webp.labels
# Converting Random479_glared.png → Random479_glared.webp
# Renaming labels: Random479_glared.labels → Random479_glared.webp.labels
# Converting Random488_glared.png → Random488_glared.webp
# Renaming labels: Random488_glared.labels → Random488_glared.webp.labels
# Converting Random4_glared.png → Random4_glared.webp
# Renaming labels: Random4_glared.labels → Random4_glared.webp.labels
# Converting Random506_glared.png → Random506_glared.webp
# Renaming labels: Random506_glared.labels → Random506_glared.webp.labels
# Converting Random508_glared.png → Random508_glared.webp
# Renaming labels: Random508_glared.labels → Random508_glared.webp.labels
# Converting Random581_glared.png → Random581_glared.webp
# Renaming labels: Random581_glared.labels → Random581_glared.webp.labels
# Converting Random585_glared.png → Random585_glared.webp
# Renaming labels: Random585_glared.labels → Random585_glared.webp.labels
# Converting Random64_glared.png → Random64_glared.webp
# Renaming labels: Random64_glared.labels → Random64_glared.webp.labels
# Converting Random683_glared.png → Random683_glared.webp
# Renaming labels: Random683_glared.labels → Random683_glared.webp.labels
# Converting Random719_glared.png → Random719_glared.webp
# Renaming labels: Random719_glared.labels → Random719_glared.webp.labels
# Converting Random750_glared.png → Random750_glared.webp
# Renaming labels: Random750_glared.labels → Random750_glared.webp.labels
# Converting Random771_glared.png → Random771_glared.webp
# Renaming labels: Random771_glared.labels → Random771_glared.webp.labels
# Converting Random801_glared.png → Random801_glared.webp
# Renaming labels: Random801_glared.labels → Random801_glared.webp.labels
# Converting Random830_glared.png → Random830_glared.webp
# Renaming labels: Random830_glared.labels → Random830_glared.webp.labels
# Converting Random831_glared.png → Random831_glared.webp
# Renaming labels: Random831_glared.labels → Random831_glared.webp.labels
# Converting Random894_glared.png → Random894_glared.webp
# Renaming labels: Random894_glared.labels → Random894_glared.webp.labels
# Converting Random918_glared.png → Random918_glared.webp
# Renaming labels: Random918_glared.labels → Random918_glared.webp.labels
# Converting Random961_glared.png → Random961_glared.webp
# Renaming labels: Random961_glared.labels → Random961_glared.webp.labels
# Converting Random99_glared.png → Random99_glared.webp
# Renaming labels: Random99_glared.labels → Random99_glared.webp.labels
# Converting animals02_Zagori_On_the_road_to_Papigko_synt.jpg → animals02_Zagori_On_the_road_to_Papigko_synt.webp
# Renaming labels: animals02_Zagori_On_the_road_to_Papigko_synt.labels → animals02_Zagori_On_the_road_to_Papigko_synt.webp.labels
# Converting animals04_17_animal_casualties_so_far_in_2006_synt.jpg → animals04_17_animal_casualties_so_far_in_2006_synt.webp
# Renaming labels: animals04_17_animal_casualties_so_far_in_2006_synt.labels → animals04_17_animal_casualties_so_far_in_2006_synt.webp.labels
# Converting animals07_Aihole_Pattadakal_synt.jpg → animals07_Aihole_Pattadakal_synt.webp
# Renaming labels: animals07_Aihole_Pattadakal_synt.labels → animals07_Aihole_Pattadakal_synt.webp.labels
# Converting animals11_Cock_Pheasant_on_Romford_Road_synt.jpg → animals11_Cock_Pheasant_on_Romford_Road_synt.webp
# Renaming labels: animals11_Cock_Pheasant_on_Romford_Road_synt.labels → animals11_Cock_Pheasant_on_Romford_Road_synt.webp.labels
# Converting animals18_Goose_on_the_road_Memphis_synt.jpg → animals18_Goose_on_the_road_Memphis_synt.webp
# Renaming labels: animals18_Goose_on_the_road_Memphis_synt.labels → animals18_Goose_on_the_road_Memphis_synt.webp.labels
# Converting animals23_rhino_crossing_road_synt.jpg → animals23_rhino_crossing_road_synt.webp
# Renaming labels: animals23_rhino_crossing_road_synt.labels → animals23_rhino_crossing_road_synt.webp.labels
# Converting animals31_deer_synt.jpg → animals31_deer_synt.webp
# Renaming labels: animals31_deer_synt.labels → animals31_deer_synt.webp.labels
# Converting cones01_Beeston_MMB_A6_Middle_Street_synt.jpg → cones01_Beeston_MMB_A6_Middle_Street_synt.webp
# Renaming labels: cones01_Beeston_MMB_A6_Middle_Street_synt.labels → cones01_Beeston_MMB_A6_Middle_Street_synt.webp.labels
# Converting cones02_Broadmoor_Manhole_Cones_synt.jpg → cones02_Broadmoor_Manhole_Cones_synt.webp
# Renaming labels: cones02_Broadmoor_Manhole_Cones_synt.labels → cones02_Broadmoor_Manhole_Cones_synt.webp.labels
# Converting cones07_synt.jpg → cones07_synt.webp
# Renaming labels: cones07_synt.labels → cones07_synt.webp.labels
# Converting obstacles01_boulder_synt.jpg → obstacles01_boulder_synt.webp
# Renaming labels: obstacles01_boulder_synt.labels → obstacles01_boulder_synt.webp.labels
# Converting obstacles04_cardboard_czech_hedgehog_synt.jpg → obstacles04_cardboard_czech_hedgehog_synt.webp
# Renaming labels: obstacles04_cardboard_czech_hedgehog_synt.labels → obstacles04_cardboard_czech_hedgehog_synt.webp.labels
# Converting obstacles09_boulder3_synt.jpg → obstacles09_boulder3_synt.webp
# Renaming labels: obstacles09_boulder3_synt.labels → obstacles09_boulder3_synt.webp.labels
# Converting obstacles10_boulder4_synt.jpg → obstacles10_boulder4_synt.webp
# Renaming labels: obstacles10_boulder4_synt.labels → obstacles10_boulder4_synt.webp.labels
# Converting pedestrian_20161201_101632_leftImg8bit.png → pedestrian_20161201_101632_leftImg8bit.webp
# Renaming labels: pedestrian_20161201_101632_leftImg8bit.labels → pedestrian_20161201_101632_leftImg8bit.webp.labels
# Converting pedestrian_20161201_101809_leftImg8bit.png → pedestrian_20161201_101809_leftImg8bit.webp
# Renaming labels: pedestrian_20161201_101809_leftImg8bit.labels → pedestrian_20161201_101809_leftImg8bit.webp.labels
# Converting pedestrian_20161201_102211_leftImg8bit.png → pedestrian_20161201_102211_leftImg8bit.webp
# Renaming labels: pedestrian_20161201_102211_leftImg8bit.labels → pedestrian_20161201_102211_leftImg8bit.webp.labels
# Converting pedestrian_20161201_102527_leftImg8bit.png → pedestrian_20161201_102527_leftImg8bit.webp
# Renaming labels: pedestrian_20161201_102527_leftImg8bit.labels → pedestrian_20161201_102527_leftImg8bit.webp.labels
# Converting tr01-22-14-1-FRONT_synt.jpg → tr01-22-14-1-FRONT_synt.webp
# Renaming labels: tr01-22-14-1-FRONT_synt.labels → tr01-22-14-1-FRONT_synt.webp.labels
# Converting tr02-7-4-1-FRONT_synt.jpg → tr02-7-4-1-FRONT_synt.webp
# Renaming labels: tr02-7-4-1-FRONT_synt.labels → tr02-7-4-1-FRONT_synt.webp.labels
# Converting tr07-20-20-1-FRONT_synt.jpg → tr07-20-20-1-FRONT_synt.webp
# Renaming labels: tr07-20-20-1-FRONT_synt.labels → tr07-20-20-1-FRONT_synt.webp.labels
# Converting web_012217_fogalbion4_leftImg8bit.png → web_012217_fogalbion4_leftImg8bit.webp
# Renaming labels: web_012217_fogalbion4_leftImg8bit.labels → web_012217_fogalbion4_leftImg8bit.webp.labels
# Converting web_11111490296_c35d8415ff_leftImg8bit.png → web_11111490296_c35d8415ff_leftImg8bit.webp
# Renaming labels: web_11111490296_c35d8415ff_leftImg8bit.labels → web_11111490296_c35d8415ff_leftImg8bit.webp.labels
# Converting web_12072159786_66ec504c8d_leftImg8bit.png → web_12072159786_66ec504c8d_leftImg8bit.webp
# Renaming labels: web_12072159786_66ec504c8d_leftImg8bit.labels → web_12072159786_66ec504c8d_leftImg8bit.webp.labels
# Converting web_13811223744_5e14bfd1db_leftImg8bit.png → web_13811223744_5e14bfd1db_leftImg8bit.webp
# Renaming labels: web_13811223744_5e14bfd1db_leftImg8bit.labels → web_13811223744_5e14bfd1db_leftImg8bit.webp.labels
# Converting web_15593947834_c5711418f3_leftImg8bit.png → web_15593947834_c5711418f3_leftImg8bit.webp
# Renaming labels: web_15593947834_c5711418f3_leftImg8bit.labels → web_15593947834_c5711418f3_leftImg8bit.webp.labels
# Converting web_16488592255_c622130769_leftImg8bit.png → web_16488592255_c622130769_leftImg8bit.webp
# Renaming labels: web_16488592255_c622130769_leftImg8bit.labels → web_16488592255_c622130769_leftImg8bit.webp.labels
# Converting web_20080313_Foggy_leftImg8bit.png → web_20080313_Foggy_leftImg8bit.webp
# Renaming labels: web_20080313_Foggy_leftImg8bit.labels → web_20080313_Foggy_leftImg8bit.webp.labels
# Converting web_20111218_avalon_leftImg8bit.png → web_20111218_avalon_leftImg8bit.webp
# Renaming labels: web_20111218_avalon_leftImg8bit.labels → web_20111218_avalon_leftImg8bit.webp.labels
# Converting web_2144738053_f1a3fb42db_leftImg8bit.png → web_2144738053_f1a3fb42db_leftImg8bit.webp
# Renaming labels: web_2144738053_f1a3fb42db_leftImg8bit.labels → web_2144738053_f1a3fb42db_leftImg8bit.webp.labels
# Converting web_2269771660_d43b11e65e_leftImg8bit.png → web_2269771660_d43b11e65e_leftImg8bit.webp
# Renaming labels: web_2269771660_d43b11e65e_leftImg8bit.labels → web_2269771660_d43b11e65e_leftImg8bit.webp.labels
# Converting web_2371463150_f663cc6d21_leftImg8bit.png → web_2371463150_f663cc6d21_leftImg8bit.webp
# Renaming labels: web_8263125502_1fc2c86cc1_leftImg8bit.labels → web_8263125502_1fc2c86cc1_leftImg8bit.webp.labels
# Converting web_8546258268_5aabe6779e_leftImg8bit.png → web_8546258268_5aabe6779e_leftImg8bit.webp
# Renaming labels: web_8546258268_5aabe6779e_leftImg8bit.labels → web_8546258268_5aabe6779e_leftImg8bit.webp.labels
# Converting web_9443635508_ccb844c48d_leftImg8bit.png → web_9443635508_ccb844c48d_leftImg8bit.webp
# Renaming labels: web_9443635508_ccb844c48d_leftImg8bit.labels → web_9443635508_ccb844c48d_leftImg8bit.webp.labels
# Converting web_Foggy_Portland_leftImg8bit.png → web_Foggy_Portland_leftImg8bit.webp
# Renaming labels: web_Foggy_Portland_leftImg8bit.labels → web_Foggy_Portland_leftImg8bit.webp.labels
# Converting web_Foggy_Waldinger_leftImg8bit.png → web_Foggy_Waldinger_leftImg8bit.webp
# Renaming labels: web_Foggy_Waldinger_leftImg8bit.labels → web_Foggy_Waldinger_leftImg8bit.webp.labels
# Converting web_NCS_20160226072105_leftImg8bit.png → web_NCS_20160226072105_leftImg8bit.webp
# Renaming labels: web_NCS_20160226072105_leftImg8bit.labels → web_NCS_20160226072105_leftImg8bit.webp.labels
# Converting web_U137P200T1D308834F12DT_20100315001722_leftImg8bit.png → web_U137P200T1D308834F12DT_20100315001722_leftImg8bit.webp
# Renaming labels: web_U137P200T1D308834F12DT_20100315001722_leftImg8bit.labels → web_U137P200T1D308834F12DT_20100315001722_leftImg8bit.webp.labels
# Converting web_fog_1_leftImg8bit.png → web_fog_1_leftImg8bit.webp
# Renaming labels: web_fog_1_leftImg8bit.labels → web_fog_1_leftImg8bit.webp.labels
# Converting web_fog_5_leftImg8bit.png → web_fog_5_leftImg8bit.webp
# Renaming labels: web_fog_5_leftImg8bit.labels → web_fog_5_leftImg8bit.webp.labels
# Converting web_fog_tcr_leftImg8bit.png → web_fog_tcr_leftImg8bit.webp
# Renaming labels: web_fog_tcr_leftImg8bit.labels → web_fog_tcr_leftImg8bit.webp.labels
# Converting web_foggy_street_leftImg8bit.png → web_foggy_street_leftImg8bit.webp
# Renaming labels: web_foggy_street_leftImg8bit.labels → web_foggy_street_leftImg8bit.webp.labels
# Converting web_img_1055_leftImg8bit.png → web_img_1055_leftImg8bit.webp
# Renaming labels: web_img_1055_leftImg8bit.labels → web_img_1055_leftImg8bit.webp.labels
# Converting web_tim_thumb_leftImg8bit.png → web_tim_thumb_leftImg8bit.webp
# Renaming labels: web_tim_thumb_leftImg8bit.labels → web_tim_thumb_leftImg8bit.webp.labels
# Converting web_tumblr_n3wkxqv7Xs1sp7ozko1_leftImg8bit.png → web_tumblr_n3wkxqv7Xs1sp7ozko1_leftImg8bit.webp
# Renaming labels: web_tumblr_n3wkxqv7Xs1sp7ozko1_leftImg8bit.labels → web_tumblr_n3wkxqv7Xs1sp7ozko1_leftImg8bit.webp.labels
# Converting animals01_Guiguinto_railway_station_Calves.webp → animals01_Guiguinto_railway_station_Calves.webp
# Renaming labels: animals01_Guiguinto_railway_station_Calves.labels → animals01_Guiguinto_railway_station_Calves.webp.labels
# Converting animals01_Guiguinto_railway_station_Calves.webp → animals01_Guiguinto_railway_station_Calves.webp
# Renaming labels: animals01_Guiguinto_railway_station_Calves.webp.labels → animals01_Guiguinto_railway_station_Calves.webp.labels
# Converting animals02_Zagori_On_the_road_to_Papigko.webp → animals02_Zagori_On_the_road_to_Papigko.webp
# Renaming labels: animals02_Zagori_On_the_road_to_Papigko.labels → animals02_Zagori_On_the_road_to_Papigko.webp.labels
# Converting animals03_Zebras_in_the_road.webp → animals03_Zebras_in_the_road.webp
# Renaming labels: animals03_Zebras_in_the_road.labels → animals03_Zebras_in_the_road.webp.labels
# Converting animals04_17_animal_casualties_so_far_in_2006.webp → animals04_17_animal_casualties_so_far_in_2006.webp
# Renaming labels: animals04_17_animal_casualties_so_far_in_2006.labels → animals04_17_animal_casualties_so_far_in_2006.webp.labels
# Converting animals05_cows_near_Phonsavan_Laos.webp → animals05_cows_near_Phonsavan_Laos.webp
# Renaming labels: animals05_cows_near_Phonsavan_Laos.labels → animals05_cows_near_Phonsavan_Laos.webp.labels
# Converting animals06_sheep_roads_lambs.webp → animals06_sheep_roads_lambs.webp
# Renaming labels: animals06_sheep_roads_lambs.labels → animals06_sheep_roads_lambs.webp.labels
# Converting animals07_Aihole_Pattadakal.webp → animals07_Aihole_Pattadakal.webp
# Renaming labels: animals07_Aihole_Pattadakal.labels → animals07_Aihole_Pattadakal.webp.labels
# Converting animals08_on_the_main_street_of_village_Lin_Albania.webp → animals08_on_the_main_street_of_village_Lin_Albania.webp
# Renaming labels: animals08_on_the_main_street_of_village_Lin_Albania.labels → animals08_on_the_main_street_of_village_Lin_Albania.webp.labels
# Converting animals09_working_together.webp → animals09_working_together.webp
# Renaming labels: animals09_working_together.labels → animals09_working_together.webp.labels
# Converting animals10_bovine_cattle_beside_road.webp → animals10_bovine_cattle_beside_road.webp
# Renaming labels: animals10_bovine_cattle_beside_road.labels → animals10_bovine_cattle_beside_road.webp.labels
# Converting animals11_Cock_Pheasant_on_Romford_Road.webp → animals11_Cock_Pheasant_on_Romford_Road.webp
# Renaming labels: animals11_Cock_Pheasant_on_Romford_Road.labels → animals11_Cock_Pheasant_on_Romford_Road.webp.labels
# Converting animals12_Collared_Peccary_crossing_the_road.webp → animals12_Collared_Peccary_crossing_the_road.webp
# Renaming labels: animals12_Collared_Peccary_crossing_the_road.labels → animals12_Collared_Peccary_crossing_the_road.webp.labels
# Converting animals13_jeune_bovin_sur_la_route.webp → animals13_jeune_bovin_sur_la_route.webp
# Renaming labels: animals13_jeune_bovin_sur_la_route.labels → animals13_jeune_bovin_sur_la_route.webp.labels
# Converting animals14_Dekemhare_Road.webp → animals14_Dekemhare_Road.webp
# Renaming labels: animals14_Dekemhare_Road.labels → animals14_Dekemhare_Road.webp.labels
# Converting animals15_Doebeln_Pferdebahn.webp → animals15_Doebeln_Pferdebahn.webp
# Renaming labels: animals15_Doebeln_Pferdebahn.labels → animals15_Doebeln_Pferdebahn.webp.labels
# Converting animals16_Donkeys_of_Morocco.webp → animals16_Donkeys_of_Morocco.webp
# Renaming labels: animals16_Donkeys_of_Morocco.labels → animals16_Donkeys_of_Morocco.webp.labels
# Converting animals17_E6_near_Kvaenangen.webp → animals17_E6_near_Kvaenangen.webp
# Renaming labels: animals17_E6_near_Kvaenangen.labels → animals17_E6_near_Kvaenangen.webp.labels
# Converting animals18_Goose_on_the_road_Memphis.webp → animals18_Goose_on_the_road_Memphis.webp
# Renaming labels: animals18_Goose_on_the_road_Memphis.labels → animals18_Goose_on_the_road_Memphis.webp.labels
# Converting animals19_Porte_de_Roubaix.webp → animals19_Porte_de_Roubaix.webp
# Renaming labels: animals19_Porte_de_Roubaix.labels → animals19_Porte_de_Roubaix.webp.labels
# Converting animals20_Marcassin_Conchiglio.webp → animals20_Marcassin_Conchiglio.webp
# Renaming labels: animals20_Marcassin_Conchiglio.labels → animals20_Marcassin_Conchiglio.webp.labels
# Converting animals21_On_The_Road_to_Gondar_Ethiopia.webp → animals21_On_The_Road_to_Gondar_Ethiopia.webp
# Renaming labels: animals21_On_The_Road_to_Gondar_Ethiopia.labels → animals21_On_The_Road_to_Gondar_Ethiopia.webp.labels
# Converting animals22_red_fox_on_road.webp → animals22_red_fox_on_road.webp
# Renaming labels: animals22_red_fox_on_road.labels → animals22_red_fox_on_road.webp.labels
# Converting animals23_rhino_crossing_road.webp → animals23_rhino_crossing_road.webp
# Renaming labels: animals23_rhino_crossing_road.labels → animals23_rhino_crossing_road.webp.labels
# Converting animals24_Sheep_Herders_Block_the_Road_Kaleybar_to_Eskanlu.webp → animals24_Sheep_Herders_Block_the_Road_Kaleybar_to_Eskanlu.webp
# Renaming labels: animals24_Sheep_Herders_Block_the_Road_Kaleybar_to_Eskanlu.labels → animals24_Sheep_Herders_Block_the_Road_Kaleybar_to_Eskanlu.webp.labels
# Converting animals25_jablonna_dziki.webp → animals25_jablonna_dziki.webp
# Renaming labels: animals25_jablonna_dziki.labels → animals25_jablonna_dziki.webp.labels
# Converting animals26_Unnamed_Road_Kazakhstan.webp → animals26_Unnamed_Road_Kazakhstan.webp
# Renaming labels: animals26_Unnamed_Road_Kazakhstan.labels → animals26_Unnamed_Road_Kazakhstan.webp.labels
# Converting animals27_wildlife_bear.webp → animals27_wildlife_bear.webp
# Renaming labels: animals27_wildlife_bear.labels → animals27_wildlife_bear.webp.labels
# Converting animals28.webp → animals28.webp
# Renaming labels: animals28.labels → animals28.webp.labels
# Converting animals29_Zebra_Crossing_Abbey_Road_Style.webp → animals29_Zebra_Crossing_Abbey_Road_Style.webp
# Renaming labels: animals29_Zebra_Crossing_Abbey_Road_Style.labels → animals29_Zebra_Crossing_Abbey_Road_Style.webp.labels
# Converting animals30.webp → animals30.webp
# Renaming labels: animals30.labels → animals30.webp.labels
# Converting animals31_deer.webp → animals31_deer.webp
# Renaming labels: animals31_deer.labels → animals31_deer.webp.labels
# Converting cones01_Beeston_MMB_A6_Middle_Street.webp → cones01_Beeston_MMB_A6_Middle_Street.webp
# Renaming labels: cones01_Beeston_MMB_A6_Middle_Street.labels → cones01_Beeston_MMB_A6_Middle_Street.webp.labels
# Converting cones02_Broadmoor_Manhole_Cones.webp → cones02_Broadmoor_Manhole_Cones.webp
# Renaming labels: cones02_Broadmoor_Manhole_Cones.labels → cones02_Broadmoor_Manhole_Cones.webp.labels
# Converting cones03_Bang_Na_Trat_Highway.webp → cones03_Bang_Na_Trat_Highway.webp
# Renaming labels: cones03_Bang_Na_Trat_Highway.labels → cones03_Bang_Na_Trat_Highway.webp.labels
# Converting cones04_Federation.webp → cones04_Federation.webp
# Renaming labels: cones04_Federation.labels → cones04_Federation.webp.labels
# Converting cones05_Corner_of_Kingsley_Park.webp → cones05_Corner_of_Kingsley_Park.webp
# Renaming labels: cones05_Corner_of_Kingsley_Park.labels → cones05_Corner_of_Kingsley_Park.webp.labels
# Converting cones06_VnA_traffic_cones.webp → cones06_VnA_traffic_cones.webp
# Renaming labels: cones06_VnA_traffic_cones.labels → cones06_VnA_traffic_cones.webp.labels
# Converting cones07.webp → cones07.webp
# Renaming labels: cones07.labels → cones07.webp.labels
# Converting cones08_can.webp → cones08_can.webp
# Renaming labels: cones08_can.labels → cones08_can.webp.labels
# Converting lost_tires03.webp → lost_tires03.webp
# Renaming labels: lost_tires03.labels → lost_tires03.webp.labels
# Converting lost_tires08.webp → lost_tires08.webp
# Renaming labels: lost_tires08.labels → lost_tires08.webp.labels
# Converting lost_tires09.webp → lost_tires09.webp
# Renaming labels: lost_tires09.labels → lost_tires09.webp.labels
# Converting obstacles01_boulder.webp → obstacles01_boulder.webp
# Renaming labels: obstacles01_boulder.labels → obstacles01_boulder.webp.labels
# Converting obstacles02_rock.webp → obstacles02_rock.webp
# Renaming labels: obstacles02_rock.labels → obstacles02_rock.webp.labels
# Converting obstacles03_cardboard_czech_hedgehog.webp → obstacles03_cardboard_czech_hedgehog.webp
# Renaming labels: obstacles03_cardboard_czech_hedgehog.labels → obstacles03_cardboard_czech_hedgehog.webp.labels
# Converting obstacles04_cardboard_czech_hedgehog.webp → obstacles04_cardboard_czech_hedgehog.webp
# Renaming labels: obstacles04_cardboard_czech_hedgehog.labels → obstacles04_cardboard_czech_hedgehog.webp.labels
# Converting obstacles05_cardboard_czech_hedgehog.webp → obstacles05_cardboard_czech_hedgehog.webp
# Renaming labels: obstacles05_cardboard_czech_hedgehog.labels → obstacles05_cardboard_czech_hedgehog.webp.labels
# Converting obstacles06_cardboard_czech_hedgehog.webp → obstacles06_cardboard_czech_hedgehog.webp
# Renaming labels: obstacles06_cardboard_czech_hedgehog.labels → obstacles06_cardboard_czech_hedgehog.webp.labels
# Converting obstacles07_czech_hedgehog.webp → obstacles07_czech_hedgehog.webp
# Renaming labels: obstacles07_czech_hedgehog.labels → obstacles07_czech_hedgehog.webp.labels
# Converting obstacles08_boulder2.webp → obstacles08_boulder2.webp
# Renaming labels: obstacles08_boulder2.labels → obstacles08_boulder2.webp.labels
# Converting obstacles09_boulder3.webp → obstacles09_boulder3.webp
# Renaming labels: obstacles09_boulder3.labels → obstacles09_boulder3.webp.labels
# Converting obstacles10_boulder4.webp → obstacles10_boulder4.webp
# Renaming labels: obstacles10_boulder4.labels → obstacles10_boulder4.webp.labels
# Converting obstacles11_boulder5.webp → obstacles11_boulder5.webp
# Renaming labels: obstacles11_boulder5.labels → obstacles11_boulder5.webp.labels
# Converting obstacles12_rocks2.webp → obstacles12_rocks2.webp
# Renaming labels: obstacles12_rocks2.labels → obstacles12_rocks2.webp.labels
# Converting obstacles12_rocks4.webp → obstacles12_rocks4.webp
# Renaming labels: obstacles12_rocks4.labels → obstacles12_rocks4.webp.labels
# Converting obstacles12_rocks5.webp → obstacles12_rocks5.webp
# Renaming labels: obstacles12_rocks5.labels → obstacles12_rocks5.webp.labels
# Converting obstacles12_rocks6.webp → obstacles12_rocks6.webp
# Renaming labels: obstacles12_rocks6.labels → obstacles12_rocks6.webp.labels
# Converting vehicle01_man_carrying_dry_grass_on_bicycle.webp → vehicle01_man_carrying_dry_grass_on_bicycle.webp
# Renaming labels: vehicle01_man_carrying_dry_grass_on_bicycle.labels → vehicle01_man_carrying_dry_grass_on_bicycle.webp.labels
# Converting vehicle02_Broadmoor_Cones_Skidloader.webp → vehicle02_Broadmoor_Cones_Skidloader.webp
# Renaming labels: vehicle02_Broadmoor_Cones_Skidloader.labels → vehicle02_Broadmoor_Cones_Skidloader.webp.labels
# Converting vehicle03_Fuhrwerke_in_China.webp → vehicle03_Fuhrwerke_in_China.webp
# Renaming labels: vehicle03_Fuhrwerke_in_China.labels → vehicle03_Fuhrwerke_in_China.webp.labels
# Done. Converted all entries to .webp and updated frame_list.json.

# %%
from pathlib import Path
from PIL import Image
import json
import shutil

# ====== CONFIGURE THESE ======
DATASET_ROOT = Path("/home/tzh005/ECE253Project/detecting-the-unexpected/datasets/dataset_RoadAnomaly")
TARGET_EXT   = ".webp"   # change to ".png" if you prefer
DELETE_OLD   = False     # set True after you verify everything works
# =============================

frames_dir = DATASET_ROOT / "frames"
json_path  = DATASET_ROOT / "frame_list.json"

frame_list = json.loads(json_path.read_text())
new_frame_list = []

# Candidate source extensions we'll look for
src_exts = [".png", ".jpg", ".jpeg", ".JPG", ".JPEG", ".PNG", ".webp", ".WEBP"]

for old_name in frame_list:
    # We only trust the stem; extension can be anything
    stem = Path(old_name).stem                 # e.g. "IMG_4088"
    target_name = stem + TARGET_EXT           # e.g. "IMG_4088.webp"
    target_img_path = frames_dir / target_name

    # 1) Find existing image file for this stem
    src_img_path = None
    for e in src_exts:
        cand = frames_dir / (stem + e)
        if cand.exists():
            src_img_path = cand
            break

    if src_img_path is None:
        print(f"[WARN] No image found for stem '{stem}' (skipping conversion)")
    else:
        if target_img_path.exists():
            print(f"[SKIP IMG] {target_name} already exists")
        else:
            print(f"[CONVERT IMG] {src_img_path.name} -> {target_name}")
            img = Image.open(src_img_path).convert("RGB")
            img.save(target_img_path, TARGET_EXT.lstrip("."), quality=95)

        if DELETE_OLD and src_img_path.exists() and src_img_path.suffix.lower() != TARGET_EXT.lower():
            print(f"[DELETE OLD IMG] {src_img_path.name}")
            src_img_path.unlink()

    # 2) Normalize label folder to stem.labels (NO extension before .labels)
    desired_label_dir = frames_dir / f"{stem}.labels"

    # Possible existing label directory names
    label_candidates = [
        frames_dir / f"{old_name}.labels",      # e.g. IMG_4088.JPG.labels
        frames_dir / f"{stem}.labels",          # e.g. IMG_4088.labels
        frames_dir / f"{target_name}.labels",   # e.g. IMG_4088.webp.labels (if created accidentally)
    ]

    found_label_dir = None
    for cand in label_candidates:
        if cand.exists():
            found_label_dir = cand
            break

    if found_label_dir is None:
        print(f"[WARN] No label dir found for stem '{stem}'")
    elif found_label_dir != desired_label_dir:
        print(f"[RENAME LABELS] {found_label_dir.name} -> {desired_label_dir.name}")
        if desired_label_dir.exists() and desired_label_dir != found_label_dir:
            backup = desired_label_dir.with_name(desired_label_dir.name + ".bak")
            print(f"  [BACKUP] {desired_label_dir.name} -> {backup.name}")
            shutil.move(str(desired_label_dir), str(backup))
        shutil.move(str(found_label_dir), str(desired_label_dir))

    # 3) Record the new filename (with TARGET_EXT) for frame_list.json
    new_frame_list.append(target_name)

# 4) Save updated frame_list.json
with open(json_path, "w") as f:
    json.dump(new_frame_list, f, indent=2)

print("Done.")
print("All entries in frame_list.json now use extension:", TARGET_EXT)
print("Label folders are normalized to '<stem>.labels'.")
# Out:
# [SKIP IMG] IMG_4088.webp already exists
# [SKIP IMG] IMG_4089.webp already exists
# [SKIP IMG] IMG_4090.webp already exists
# [SKIP IMG] IMG_4091.webp already exists
# [SKIP IMG] IMG_4092.webp already exists
# [SKIP IMG] IMG_4093.webp already exists
# [SKIP IMG] IMG_4094.webp already exists
# [SKIP IMG] IMG_4095.webp already exists
# [SKIP IMG] IMG_4097.webp already exists
# [SKIP IMG] IMG_4098.webp already exists
# [SKIP IMG] IMG_4099.webp already exists
# [SKIP IMG] IMG_4100.webp already exists
# [SKIP IMG] IMG_4101.webp already exists
# [SKIP IMG] Random1205_glared.webp already exists
# [SKIP IMG] Random1269_glared.webp already exists
# [SKIP IMG] Random1334_glared.webp already exists
# [SKIP IMG] Random133_glared.webp already exists
# [SKIP IMG] Random1360_glared.webp already exists
# [SKIP IMG] Random1399_glared.webp already exists
# [SKIP IMG] Random1416_glared.webp already exists
# [SKIP IMG] Random1498_glared.webp already exists
# [SKIP IMG] Random149_glared.webp already exists
# [SKIP IMG] Random154_glared.webp already exists
# [SKIP IMG] Random15_glared.webp already exists
# [SKIP IMG] Random166_glared.webp already exists
# [SKIP IMG] Random167_glared.webp already exists
# [SKIP IMG] Random1722_glared.webp already exists
# [SKIP IMG] Random1832_glared.webp already exists
# [SKIP IMG] Random1974_glared.webp already exists
# [SKIP IMG] Random1975_glared.webp already exists
# [SKIP IMG] Random1_glared.webp already exists
# [SKIP IMG] Random204_glared.webp already exists
# [SKIP IMG] Random2140_glared.webp already exists
# [SKIP IMG] Random2161_glared.webp already exists
# [SKIP IMG] Random2270_glared.webp already exists
# [SKIP IMG] Random235_glared.webp already exists
# [SKIP IMG] Random2374_glared.webp already exists
# [SKIP IMG] Random2494_glared.webp already exists
# [SKIP IMG] Random24_glared.webp already exists
# [SKIP IMG] Random2503_glared.webp already exists
# [SKIP IMG] Random2504_glared.webp already exists
# [SKIP IMG] Random251_glared.webp already exists
# [SKIP IMG] Random2545_glared.webp already exists
# [SKIP IMG] Random2612_glared.webp already exists
# [SKIP IMG] Random2632_glared.webp already exists
# [SKIP IMG] Random2669_glared.webp already exists
# [SKIP IMG] Random2676_glared.webp already exists
# [SKIP IMG] Random2679_glared.webp already exists
# [SKIP IMG] Random2680_glared.webp already exists
# [SKIP IMG] Random26_glared.webp already exists
# [SKIP IMG] Random2762_glared.webp already exists
# [SKIP IMG] Random292_glared.webp already exists
# [SKIP IMG] Random2931_glared.webp already exists
# [SKIP IMG] Random2975_glared.webp already exists
# [SKIP IMG] Random3038_glared.webp already exists
# [SKIP IMG] Random3126_glared.webp already exists
# [SKIP IMG] Random3139_glared.webp already exists
# [SKIP IMG] Random31_glared.webp already exists
# [SKIP IMG] Random3203_glared.webp already exists
# [SKIP IMG] Random3220_glared.webp already exists
# [SKIP IMG] Random3270_glared.webp already exists
# [SKIP IMG] Random3299_glared.webp already exists
# [SKIP IMG] Random3461_glared.webp already exists
# [SKIP IMG] Random3568_glared.webp already exists
# [SKIP IMG] Random358_glared.webp already exists
# [SKIP IMG] Random385_glared.webp already exists
# [SKIP IMG] Random386_glared.webp already exists
# [SKIP IMG] Random461_glared.webp already exists
# [SKIP IMG] Random473_glared.webp already exists
# [SKIP IMG] Random479_glared.webp already exists
# [SKIP IMG] Random488_glared.webp already exists
# [SKIP IMG] Random4_glared.webp already exists
# [SKIP IMG] Random506_glared.webp already exists
# [SKIP IMG] Random508_glared.webp already exists
# [SKIP IMG] Random581_glared.webp already exists
# [SKIP IMG] Random585_glared.webp already exists
# [SKIP IMG] Random64_glared.webp already exists
# [SKIP IMG] Random683_glared.webp already exists
# [SKIP IMG] Random719_glared.webp already exists
# [SKIP IMG] Random750_glared.webp already exists
# [SKIP IMG] Random771_glared.webp already exists
# [SKIP IMG] Random801_glared.webp already exists
# [SKIP IMG] Random830_glared.webp already exists
# [SKIP IMG] Random831_glared.webp already exists
# [SKIP IMG] Random894_glared.webp already exists
# [SKIP IMG] Random918_glared.webp already exists
# [SKIP IMG] Random961_glared.webp already exists
# [SKIP IMG] Random99_glared.webp already exists
# [SKIP IMG] animals02_Zagori_On_the_road_to_Papigko_synt.webp already exists
# [SKIP IMG] animals04_17_animal_casualties_so_far_in_2006_synt.webp already exists
# [SKIP IMG] animals07_Aihole_Pattadakal_synt.webp already exists
# [SKIP IMG] animals11_Cock_Pheasant_on_Romford_Road_synt.webp already exists
# [SKIP IMG] animals14_Dekemhare_Road.webp already exists
# [SKIP IMG] animals15_Doebeln_Pferdebahn.webp already exists
# [SKIP IMG] animals16_Donkeys_of_Morocco.webp already exists
# [SKIP IMG] animals17_E6_near_Kvaenangen.webp already exists
# [SKIP IMG] animals18_Goose_on_the_road_Memphis.webp already exists
# [SKIP IMG] animals19_Porte_de_Roubaix.webp already exists
# [SKIP IMG] animals20_Marcassin_Conchiglio.webp already exists
# [SKIP IMG] animals21_On_The_Road_to_Gondar_Ethiopia.webp already exists
# [SKIP IMG] animals22_red_fox_on_road.webp already exists
# [SKIP IMG] animals23_rhino_crossing_road.webp already exists
# [SKIP IMG] animals24_Sheep_Herders_Block_the_Road_Kaleybar_to_Eskanlu.webp already exists
# [SKIP IMG] animals25_jablonna_dziki.webp already exists
# [SKIP IMG] animals26_Unnamed_Road_Kazakhstan.webp already exists
# [SKIP IMG] animals27_wildlife_bear.webp already exists
# [SKIP IMG] animals28.webp already exists
# [SKIP IMG] animals29_Zebra_Crossing_Abbey_Road_Style.webp already exists
# [SKIP IMG] animals30.webp already exists
# [SKIP IMG] animals31_deer.webp already exists
# [SKIP IMG] cones01_Beeston_MMB_A6_Middle_Street.webp already exists
# [SKIP IMG] cones02_Broadmoor_Manhole_Cones.webp already exists
# [SKIP IMG] cones03_Bang_Na_Trat_Highway.webp already exists
# [SKIP IMG] cones04_Federation.webp already exists
# [SKIP IMG] cones05_Corner_of_Kingsley_Park.webp already exists
# [SKIP IMG] cones06_VnA_traffic_cones.webp already exists
# [SKIP IMG] cones07.webp already exists
# [SKIP IMG] cones08_can.webp already exists
# [SKIP IMG] lost_tires03.webp already exists
# [SKIP IMG] lost_tires08.webp already exists
# [SKIP IMG] lost_tires09.webp already exists
# [SKIP IMG] obstacles01_boulder.webp already exists
# [SKIP IMG] obstacles02_rock.webp already exists
# [SKIP IMG] obstacles03_cardboard_czech_hedgehog.webp already exists
# [SKIP IMG] obstacles04_cardboard_czech_hedgehog.webp already exists
# [SKIP IMG] obstacles05_cardboard_czech_hedgehog.webp already exists
# [SKIP IMG] obstacles06_cardboard_czech_hedgehog.webp already exists
# [SKIP IMG] obstacles07_czech_hedgehog.webp already exists
# [SKIP IMG] obstacles08_boulder2.webp already exists
# [SKIP IMG] obstacles09_boulder3.webp already exists
# [SKIP IMG] obstacles10_boulder4.webp already exists
# [SKIP IMG] obstacles11_boulder5.webp already exists
# [SKIP IMG] obstacles12_rocks2.webp already exists
# [SKIP IMG] obstacles12_rocks4.webp already exists
# [SKIP IMG] obstacles12_rocks5.webp already exists
# [SKIP IMG] obstacles12_rocks6.webp already exists
# [SKIP IMG] vehicle01_man_carrying_dry_grass_on_bicycle.webp already exists
# [SKIP IMG] vehicle02_Broadmoor_Cones_Skidloader.webp already exists
# [SKIP IMG] vehicle03_Fuhrwerke_in_China.webp already exists
# Done.
# All entries in frame_list.json now use extension: .webp
# Label folders are normalized to '<stem>.labels'.
